# %%
import statsmodels.api as sm
import pandas as pd
from matplotlib import pyplot as plt

# %%
dta = sm.datasets.co2.load_pandas().data
dta.plot();
plt.title('Niveles de CO2')
plt.ylabel('Partes por millon')
plt.xlabel('Año')
plt.show()

# %%
dta.index
# Out:
# DatetimeIndex(['1958-03-29', '1958-04-05', '1958-04-12', '1958-04-19',
#                '1958-04-26', '1958-05-03', '1958-05-10', '1958-05-17',
#                '1958-05-24', '1958-05-31',
#                ...
#                '2001-10-27', '2001-11-03', '2001-11-10', '2001-11-17',
#                '2001-11-24', '2001-12-01', '2001-12-08', '2001-12-15',
#                '2001-12-22', '2001-12-29'],
#               dtype='datetime64[ns]', length=2284, freq='W-SAT')

# %%
import urllib
import numpy as np

# %%
import yfinance as yf

# %%
ticker_google ='GOGL'
start_date = '2025-01-01'
end_date = '2025-12-31'
df_google = yf.download(ticker_google, start=start_date, end=end_date)
# Out:
# C:\Users\karol\AppData\Local\Temp\ipykernel_24052\252304190.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_google = yf.download(ticker_google, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
df_google
# Out:
# Price          Close      High       Low      Open   Volume
# Ticker          GOGL      GOGL      GOGL      GOGL     GOGL
# Date
# 2025-01-02  9.110226  9.178503  8.993178  9.012685  1078855
# 2025-01-03  8.885882  9.134609  8.837113  9.110225  1096250
# 2025-01-06  8.622525  8.905391  8.603017  8.876129  1636405
# 2025-01-07  8.739573  8.798098  8.642033  8.681049  1491655
# 2025-01-08  8.768835  8.827359  8.505478  8.603017  1767857
# ...              ...       ...       ...       ...      ...
# 2025-08-14  7.770000  8.260000  7.740000  8.260000  2787361
# 2025-08-15  8.000000  8.050000  7.880000  7.890000  1781726
# 2025-08-18  8.200000  8.230000  8.000000  8.050000  1470387
# 2025-08-19  7.980000  8.280000  7.850000  8.280000  3236471
# 2025-08-20  7.980000  7.980000  7.980000  7.980000        0
#
# [158 rows x 5 columns]
